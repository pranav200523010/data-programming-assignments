# %% [markdown]
# # Question 1

# %% [raw]
# Occupations
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called users
# Step 4. Discover what is the mean age per occupation
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least
# Step 6. For each occupation, calculate the minimum and maximum ages
# Step 7. For each combination of occupation and sex, calculate the mean
# Step 8. For each occupation present the percentage of women and men

# %%
import pandas as pd

users = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user", sep = "|")
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# #### Step 4. Discover what is the mean age per occupation

# %%
users.groupby("occupation").age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# #### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
users.rename(columns={"sex":"gender"}, inplace=True)

gender_inn = users.groupby("occupation")["gender"].value_counts(normalize=True)*100

genderspec = pd.DataFrame(gender_inn)

genderspec.rename(columns={"gender":"percent"}, inplace=True)

Gender_sel = pd.DataFrame(genderspec.reset_index(level=["occupation", "gender"]))

male_ratio = Gender_sel[Gender_sel["gender"] == "M"].sort_values(by="percent",ascending=False)

male_ratio
# Out:
#        occupation gender     percent
# 4          doctor      M  100.000000
# 7        engineer      M   97.014925
# 37     technician      M   96.296296
# 29        retired      M   92.857143
# 27     programmer      M   90.909091
# 11      executive      M   90.625000
# 33      scientist      M   90.322581
# 9   entertainment      M   88.888889
# 17         lawyer      M   83.333333
# 31       salesman      M   75.000000
# 5        educator      M   72.631579
# 35        student      M   69.387755
# 25          other      M   65.714286
# 21      marketing      M   61.538462
# 39         writer      M   57.777778
# 23           none      M   55.555556
# 0   administrator      M   54.430380
# 2          artist      M   53.571429
# 20      librarian      M   43.137255
# 14     healthcare      M   31.250000
# 16      homemaker      M   14.285714

# %% [markdown]
# #### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
users.groupby("occupation").age.agg([min, max])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# #### Step 7. For each combination of occupation and sex, calculate the mean

# %%
calmean= users.groupby(["occupation", "gender"]).age.mean()
Gender_sel
# Out:
#        occupation gender     percent
# 0   administrator      M   54.430380
# 1   administrator      F   45.569620
# 2          artist      M   53.571429
# 3          artist      F   46.428571
# 4          doctor      M  100.000000
# 5        educator      M   72.631579
# 6        educator      F   27.368421
# 7        engineer      M   97.014925
# 8        engineer      F    2.985075
# 9   entertainment      M   88.888889
# 10  entertainment      F   11.111111
# 11      executive      M   90.625000
# 12      executive      F    9.375000
# 13     healthcare      F   68.750000
# 14     healthcare      M   31.250000
# 15      homemaker      F   85.714286
# 16      homemaker      M   14.285714
# 17         lawyer      M   83.333333
# 18         lawyer      F   16.666667
# 19      librarian      F   56.862745
# 20      librarian      M   43.137255
# 21      marketing      M   61.538462
# 22      marketing      F   38.461538
# 23           none      M   55.555556
# ...

# %% [markdown]
# #### Step 8. For each occupation present the percentage of women and men

# %%
users.groupby(['occupation', 'gender']).gender.count()
# Out:
# occupation     gender
# administrator  F          36
#                M          43
# artist         F          13
#                M          15
# doctor         M           7
# educator       F          26
#                M          69
# engineer       F           2
#                M          65
# entertainment  F           2
#                M          16
# executive      F           3
#                M          29
# healthcare     F          11
#                M           5
# homemaker      F           6
#                M           1
# lawyer         F           2
#                M          10
# librarian      F          29
#                M          22
# marketing      F          10
#                M          16
# none           F           4
#                M           5
# other          F          36
#                M          69
# programmer     F           6
#                M          60
# retired        F           1
#                M          13
# ...

# %% [markdown]
# # Question 2

# %% [raw]
# Euro Teams
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address
# Step 3. Assign it to a variable called euro12
# Step 4. Select only the Goal column
# Step 5. How many team participated in the Euro2012?
# Step 6. What is the number of columns in the dataset?
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline
# Step 8. Sort the teams by Red Cards, then to Yellow Cards
# Step 9. Calculate the mean Yellow Cards given per Team
# Step 10. Filter teams that scored more than 6 goals
# Step 11. Select the teams that start with G
# Step 12. Select the first 7 columns
# Step 13. Select all columns except the last 3
# Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
euro12 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')

euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# #### Step 5. How many team participated in the Euro2012?

# %%
euro12['Team'].count()
# Out:
# 16

# %% [markdown]
# #### Step 6. What is the number of columns in the dataset?

# %%
len(euro12.columns)
# Out:
# 35

# %% [markdown]
# #### Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline = euro12[['Team','Yellow Cards','Red Cards']]

discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# #### Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
discipline.sort_values(by = ['Red Cards','Yellow Cards'])
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1

# %% [markdown]
# #### Step 9. Calculate the mean Yellow Cards given per Team

# %%
discipline['Yellow Cards'].mean()
# Out:
# 7.4375

# %% [markdown]
# #### Step 10. Filter teams that scored more than 6 goals

# %%
euro12[euro12['Goals'] > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %% [markdown]
# ####  Step 11. Select the teams that start with G

# %%
euro12[euro12.Team.str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %% [markdown]
# #### Step 12. Select the first 7 columns

# %%
euro12.head(7)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# ...

# %% [markdown]
# #### Step 13. Select all columns except the last 3

# %%
euro12.iloc[:, :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# #### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
euro12.loc[euro12.Team.isin(['England', 'Italy', 'Russia']), ['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# # Question 3

# %% [raw]
# Housing
# Step 1. Import the necessary libraries
# Step 2. Create 3 differents Series, each of length 100, as follows:
# • The first a random number from 1 to 4
# • The second a random number from 1 to 3
# • The third a random number from 10,000 to 30,000
# Step 3. Create a DataFrame by joinning the Series by column
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
# Step 6. Ops it seems it is going only until index 99. Is it true?
# Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
import pandas as pd
import numpy as np
import random

# %%
first = pd.Series(np.random.randint(1,5,100))

first
# Out:
# 0     4
# 1     4
# 2     4
# 3     1
# 4     3
#      ..
# 95    2
# 96    3
# 97    3
# 98    1
# 99    2
# Length: 100, dtype: int64

# %%
second = pd.Series(np.random.randint(1,4,100))

second
# Out:
# 0     3
# 1     1
# 2     3
# 3     2
# 4     1
#      ..
# 95    2
# 96    3
# 97    1
# 98    3
# 99    2
# Length: 100, dtype: int64

# %%
third = pd.Series(np.random.randint(10000,30000,100))

third
# Out:
# 0     29665
# 1     22003
# 2     20178
# 3     23587
# 4     15752
#       ...
# 95    20760
# 96    15120
# 97    25246
# 98    22960
# 99    29446
# Length: 100, dtype: int64

# %% [markdown]
# #### Step 3. Create a DataFrame by joinning the Series by column

# %%
sercol = pd.concat([first,second,third],axis = 1)

sercol.head()
# Out:
#    0  1      2
# 0  4  3  29665
# 1  4  1  22003
# 2  4  3  20178
# 3  1  2  23587
# 4  3  1  15752

# %% [markdown]
# #### Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
sercol.columns = ['bedrs','bathrs','price_sqr_meter']
sercol.head()
# Out:
#    bedrs  bathrs  price_sqr_meter
# 0      4       3            29665
# 1      4       1            22003
# 2      4       3            20178
# 3      1       2            23587
# 4      3       1            15752

# %% [markdown]
# #### Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

# %%
bigcolumn = pd.concat([first,second,third], axis = 0)

bigcolumn
# Out:
# 0         4
# 1         4
# 2         4
# 3         1
# 4         3
#       ...
# 95    20760
# 96    15120
# 97    25246
# 98    22960
# 99    29446
# Length: 300, dtype: int64

# %% [markdown]
# #### Step 6. Ops it seems it is going only until index 99. Is it true?

# %%
len(bigcolumn)
# Out:
# 300

# %% [markdown]
# #### Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
bigcolumn.reset_index(drop = True, inplace = True)

bigcolumn
# Out:
# 0          4
# 1          4
# 2          4
# 3          1
# 4          3
#        ...
# 295    20760
# 296    15120
# 297    25246
# 298    22960
# 299    29446
# Length: 300, dtype: int64

# %% [markdown]
# # Question 4

# %% [raw]
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from the attached file wind.txt
# Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.
# Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.
# Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].
# Step 6. Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below.
# Step 7. Compute how many non-missing values there are in total.
# Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# A single number for the entire dataset.
# Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
# A different set of numbers for each location.
# Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
# A different set of numbers for each day.
# Step 11. Find the average windspeed in January for each location.
# Treat January 1961 and January 1962 both as January.
# Step 12. Downsample the record to a yearly frequency for each location.
# Step 13. Downsample the record to a monthly frequency for each location.
# Step 14. Downsample the record to a weekly frequency for each location.
# Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
pd.read_csv("wind.txt")
# Out:
#      Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
# 0     61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 1...
# 1     61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 1...
# 2     61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 1...
# 3     61  1  4 10.58  6.63 11.75  4.58  4.54  2.88  ...
# 4     61  1  5 13.33 13.25 11.42  6.17 10.71  8.21 1...
# ...                                                 ...
# 6569  78 12 27 17.58 16.96 17.62  8.08 13.21 11.67 1...
# 6570  78 12 28 13.21  5.46 13.46  5.00  8.12  9.42 1...
# 6571  78 12 29 14.00 10.29 14.42  8.71  9.71 10.54 1...
# 6572  78 12 30 18.50 14.04 21.29  9.13 12.75  9.71 1...
# 6573  78 12 31 20.33 17.41 27.29  9.59 12.08 10.13 1...
#
# [6574 rows x 1 columns]

# %%
import pandas as pd
import numpy as np
import datetime

data = pd.read_csv('wind.txt', sep = "\s+", parse_dates = [[0,1,2]])

data.head()
# Out:
#     Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# #### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
def fix_year2061(x):
    
  year = x.year - 100 if x.year > 1978 else x.year

  return datetime.date(year, x.month, x.day)

data['Yr_Mo_Dy'] = data['Yr_Mo_Dy'].apply(fix_year2061)

data.head()
# Out:
#      Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# #### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data["Yr_Mo_Dy"] = pd.to_datetime(data["Yr_Mo_Dy"])

data = data.set_index('Yr_Mo_Dy')

data.head()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# Yr_Mo_Dy
# 1961-01-01  12.58  18.50  15.04
# 1961-01-02   9.67  17.54  13.83
# 1961-01-03   7.67  12.75  12.71
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83

# %% [markdown]
# #### Step 6. Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below.

# %%
data.isnull().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %% [markdown]
# #### Step 7. Compute how many non-missing values there are in total.

# %%
null_count = data.notnull().sum()

null_count
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %% [markdown]
# #### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times. A single number for the entire dataset.

# %%
meanwind = data.sum().sum() / data.notna().sum().sum()

meanwind
# Out:
# 10.227883764282181

# %% [markdown]
# #### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days. A different set of numbers for each location.

# %%
loc_stats = pd.DataFrame()

loc_stats = data.describe(percentiles=[])

loc_stats
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6568.000000  6571.000000  6572.000000  6569.000000  6572.000000
# mean     12.362987    10.644314    11.660526     6.306468    10.455834
# std       5.618413     5.267356     5.008450     3.605811     4.936125
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 50%      11.710000    10.170000    10.920000     5.750000     9.960000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6574.000000  6571.000000  6572.000000  6571.000000  6573.000000
# mean      7.092254     9.797343     8.495053     8.493590     8.707332
# std       3.968683     4.977555     4.499449     4.166872     4.503954
# min       0.000000     0.000000     0.000000     0.000000     0.040000
# 50%       6.830000     9.210000     8.080000     8.170000     8.290000
# ...

# %% [markdown]
# #### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day. A different set of numbers for each day.

# %%
day_stats = pd.DataFrame()

day_stats['min'] = data.min(axis = 1)

day_stats['max'] = data.max(axis = 1) 

day_stats['mean'] = data.mean(axis = 1) 

day_stats['std'] = data.std(axis = 1)

day_stats.head()
# Out:
#              min    max       mean       std
# Yr_Mo_Dy
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356

# %% [markdown]
# #### Step 11. Find the average windspeed in January for each location. Treat January 1961 and January 1962 both as January.

# %%
windjan = data.loc[data.index.month == 1].mean()

windjan
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# #### Step 12. Downsample the record to a yearly frequency for each location.

# %%
yearly_freq = data.groupby(data.index.to_period('A')).mean()

yearly_freq
# Out:
#                 RPT        VAL        ROS       KIL        SHA       BIR  \
# Yr_Mo_Dy
# 1961      12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962      12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963      12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964      12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965      12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966      13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967      12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968      11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969      11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970      12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971      11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# 1972      12.463962  10.561311  12.058333  5.929699   9.430410  6.358825
# ...

# %% [markdown]
# #### Step 13. Downsample the record to a monthly frequency for each location.

# %%
monthly_freq = data.groupby(data.index.to_period('M')).mean()

monthly_freq
# Out:
#                 RPT        VAL        ROS       KIL        SHA        BIR  \
# Yr_Mo_Dy
# 1961-01   14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02   16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03   10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04   10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05    9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...             ...        ...        ...       ...        ...        ...
# 1978-08    9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09   10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10    9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11   16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12   16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %% [markdown]
# #### Step 14. Downsample the record to a weekly frequency for each location.

# %%
weekly_freq = data.groupby(data.index.to_period('W')).mean()


weekly_freq
# Out:
#                              RPT        VAL        ROS        KIL        SHA  \
# Yr_Mo_Dy
# 1960-12-26/1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN
# 1961-01-02/1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286
# 1961-01-09/1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429
# 1961-01-16/1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667
# 1961-01-23/1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857
# ...                          ...        ...        ...        ...        ...
# 1978-11-27/1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714
# 1978-12-04/1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143
# 1978-12-11/1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143
# 1978-12-18/1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714
# 1978-12-25/1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000
#
# ...

# %% [markdown]
# #### Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
weekly_windspeed = data.resample('W').agg(['min','max','mean','std'])


weekly_windspeed.loc[weekly_windspeed.index[1:53], "RPT":"MAL"] .head(10)
# Out:
#               RPT                                VAL                    \
#               min    max       mean       std    min    max       mean
# Yr_Mo_Dy
# 1961-01-08  10.58  18.50  13.541429  2.631321   6.63  16.88  11.486667
# 1961-01-15   9.04  19.75  12.468571  3.555392   3.54  12.08   8.967143
# 1961-01-22   4.92  19.83  13.204286  5.337402   3.42  14.37   9.862857
# 1961-01-29  13.62  25.04  19.880000  4.619061   9.96  23.91  16.141429
# 1961-02-05  10.58  24.21  16.827143  5.251408   9.46  24.21  15.460000
# 1961-02-12  16.00  24.54  19.684286  3.587677  11.54  21.42  16.417143
# 1961-02-19   6.04  22.50  15.130000  5.064609  11.63  20.17  15.091429
# 1961-02-26   7.79  25.80  15.221429  7.020716   7.08  21.50  13.625714
# 1961-03-05  10.96  13.33  12.101429  0.997721   8.83  17.00  12.951429
# 1961-03-12   4.88  14.79   9.376667  3.732263   8.08  16.96  11.578571
#
#                         ROS         ...        CLO              BEL         \
# ...

# %% [markdown]
# # Question 5

# %% [raw]
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called chipo.
# Step 4. See the first 10 entries
# Step 5. What is the number of observations in the dataset?
# Step 6. What is the number of columns in the dataset?
# Step 7. Print the name of all the columns.
# Step 8. How is the dataset indexed?
# Step 9. Which was the most-ordered item?
# Step 10. For the most-ordered item, how many items were ordered?
# Step 11. What was the most ordered item in the choice_description column?
# Step 12. How many items were orderd in total?
# Step 13.
# • Turn the item price into a float
# • Check the item price type
# • Create a lambda function and change the type of item price
# • Check the item price type
# Step 14. How much was the revenue for the period in the dataset?
# Step 15. How many orders were made in the period?
# Step 16. What is the average revenue amount per order?
# Step 17. How many different items are sold?

# %%
import pandas as pd
import numpy as np

chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep= '\t')

chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# #### Step 5. What is the number of observations in the dataset?

# %%
no_of_observe = chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %% [markdown]
# #### Step 6. What is the number of columns in the dataset?

# %%
no_of_col = chipo.shape

no_of_col
# Out:
# (4622, 5)

# %% [markdown]
# #### Step 7. Print the name of all the columns.

# %%
name_of_col = chipo.head(0)

name_of_col
# Out:
# Empty DataFrame
# Columns: [order_id, quantity, item_name, choice_description, item_price]
# Index: []

# %% [markdown]
# #### Step 8. How is the dataset indexed?

# %%
how_index = chipo.index

how_index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# #### Step 9. Which was the most-ordered item?

# %%
most_ordered_item = chipo.groupby(by="item_name").sum().sort_values('quantity',ascending=False).head(1)

most_ordered_item
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %% [markdown]
# #### Step 10. For the most-ordered item, how many items were ordered?

# %%
quantity_most_order = chipo.groupby(by="item_name").sum().sort_values('quantity',ascending=False).head(1)

quantity_most_order
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %% [markdown]
# #### Step 11. What was the most ordered item in the choice_description column?

# %%
most_choice = chipo.groupby(by="choice_description").sum().sort_values('quantity',ascending=False).head(1)

most_choice
# Out:
#                     order_id  quantity  item_price
# choice_description
# [Diet Coke]           123455       159      326.71

# %% [markdown]
# #### Step 12. How many items were orderd in total?

# %%
ordered_items = chipo.item_name.count()

ordered_items
# Out:
# 4622

# %% [markdown]
# #### Step 13.
# • Turn the item price into a float
# • Check the item price type
# • Create a lambda function and change the type of item price
# • Check the item price type

# %%
chipo.item_price.dtype
# Out:
# dtype('O')

# %%
turn_to_money = lambda x: float(x[1:-1])

chipo.item_price = chipo.item_price.apply(turn_to_money)

chipo.item_price.dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### Step 14. How much was the revenue for the period in the dataset?

# %%
revenue_total =  (chipo.item_price * chipo.quantity).sum()
print('Revenue is : $ '+ str(revenue_total))
# Out:
# Revenue is : $ 39237.02

# %% [markdown]
# #### Step 15. How many orders were made in the period?

# %%
orders_made = chipo.order_id.value_counts().count()

orders_made
# Out:
# 1834

# %% [markdown]
# #### Step 16. What is the average revenue amount per order?

# %%
chipo['revenue'] = chipo['quantity'] * chipo['item_price']

order_categ = chipo.groupby(by=['order_id']).sum()


print('The average revenue amount per order is:'+ str(order_categ.mean()['revenue']))
# Out:
# The average revenue amount per order is:21.39423118865867

# %% [markdown]
# #### Step 17. How many different items are sold?

# %%
diff_items_sold = chipo.item_name.value_counts().count()

diff_items_sold
# Out:
# 50

# %% [markdown]
# # Question 6

# %% [raw]
# Create a line plot showing the number of marriages and divorces per capita in the
# U.S. between 1867 and 2014. Label both lines and show the legend.
# Don't forget to label your axes!

# %%
import pandas as pd
import matplotlib.pyplot as plt

divorce_us = pd.read_csv('us-marriages-divorces-1867-2014.csv')

divorce_us.head()
# Out:
#    Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0  1867   357000.0   10000.0    36970000                 9.7
# 1  1868   345000.0   10000.0    37885000                 9.1
# 2  1869   348000.0   11000.0    38870000                 9.0
# 3  1870   352000.0   11000.0    39905000                 8.8
# 4  1871   359000.0   12000.0    41010000                 8.8
#
#    Divorces_per_1000
# 0                0.3
# 1                0.3
# 2                0.3
# 3                0.3
# 4                0.3

# %%
plt.figure(figsize=(8,5))



plt.plot(divorce_us['Year'],divorce_us['Marriages'],label='Marriages')
plt.plot(divorce_us['Year'],divorce_us['Divorces'],label='Divorces')
plt.legend(loc = 'upper left')

plt.xlabel('Year')
plt.ylabel('Count')

plt.title('number of marriages and divorces per capita in the U.S. between 1867 and 2014')



plt.show()

# %% [markdown]
# # Question 7

# %% [raw]
# Create a vertical bar chart comparing the number of marriages and divorces per
# capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!

# %%
import pandas as pd

import matplotlib.pyplot as plt

divorce_us = divorce_us [ divorce_us['Year'].apply(lambda x: x in [1900, 1950, 2000])]

years = divorce_us['Year'].values

mar_cap = divorce_us ['Marriages_per_1000'].values

div_cap = divorce_us['Divorces_per_1000'].values

width = 20

plt.figure(figsize=(10,6))

plt.bar(x = (years - width/2), height = mar_cap, color = 'y', width = width, label = 'Marriage per Capita')

plt.bar(x = (years + width/2), height = div_cap, color = 'g', width = width, label = 'Divorce per Capita')

plt.xlabel('Year')

plt.ylabel('Count')

plt.legend(loc='upper right')

plt.title('Number of marriages and divorces per capita in the U.S. between 1900, 1950, and 2000')

plt.show()

# %% [markdown]
# # Question 8

# %% [raw]
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort the actors by their kill count and label each bar with the corresponding actor's name. Don't forget to label your axes!

# %%
import pandas as pd
import matplotlib.pyplot as plt

deadliest_actors = pd.read_csv('actor_kill_counts.csv')

actor_names = deadliest_actors['Actor'].values

kill_counts = deadliest_actors['Count'].values

plt.figure(figsize=(6,10 ))

plt.barh(actor_names, kill_counts)

plt.xlabel('Year')

plt.ylabel('Count')

plt.title('Deadliest actors in Hollywood and their kill count')

plt.show()

# %% [markdown]
# # Question 9

# %% [raw]
# Create a pie chart showing the fraction of all Roman Emperors that were assassinated.
# Make sure that the pie chart is an even circle, labels the categories, and shows the percentage breakdown of the categories.

# %%
import pandas as pd
import matplotlib.pyplot as plt

roman_emp = pd.read_csv('roman-emperor-reigns.csv')

assin_emp = roman_emp [roman_emp['Cause_of_Death'].apply(lambda x: 'assassinated' in x.lower())]

assinated_count = len(assin_emp)
other_deaths = len(roman_emp) - assinated_count

plt.figure(figsize=(8, 8))

plt.pie([assinated_count, other_deaths], colors=['grey', 'yellow'], startangle=90, autopct='%2.1f%%', labels=['Assassinated', 'Other'])

plt.title('Assinated Roman Emperors')


plt.show()

# %% [markdown]
# # Question 10

# %% [raw]
# Create a scatter plot showing the relationship between the total revenue earned by arcades and the number of Computer Science PhDs awarded in the U.S. between 2000 and 2009.
# Don't forget to label your axes!
# Color each dot according to its year.

# %%
import pandas as pd
import matplotlib.pyplot as plt



comp_arcade = pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')

arcade_rev = comp_arcade['Total Arcade Revenue (billions)'].values

years = comp_arcade['Year'].values

awarded_docts = comp_arcade['Computer Science Doctorates Awarded (US)'].values

plt.figure(figsize=(10, 7))

plt.scatter(arcade_rev, awarded_docts, s=40,c=['green','red','blue','grey','orange','olive','purple','black','blue','brown'], marker='o')

plt.xlabel('Total Revenue Earned by Arcades')

plt.ylabel('Number of Computer Science Doctrates Awards')

plt.title('Total revenue earned by arcades and the number of Computer Science PhDs awarded in the U.S. between 2000 and 2009')

plt.legend(years)


plt.show()

# %% [markdown]
# ### References
# Data Visualization using Matplotlib . (n.d.). Retrieved from GeeksForGeeks: https://www.geeksforgeeks.org/data-visualization-using-matplotlib/
# How To Perform Data Visualization with Pandas . (n.d.). Retrieved from Analytics Vidhya: https://www.analyticsvidhya.com/blog/2021/07/how-to-perform-data-visualization-with-pandas/
# matplotlib.pyplot.legend . (n.d.). Retrieved from Matplotlib: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html
#
#
# Also used your python notebooks from weekly learning for the revising the concepts.
